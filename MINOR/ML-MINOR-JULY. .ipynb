# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/SHRUTI KATHURIA/Desktop/Verzeo Project/Minor/tmbd.csv")

# %%
data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
data.tail()
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10861     21  tt0060371    0.080598       0        0
# 10862  20379  tt0060472    0.065543       0        0
# 10863  39768  tt0060161    0.065141       0        0
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10861        The Endless Summer
# 10862                Grand Prix
# 10863       Beregis Avtomobilya
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...      NaN
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...      NaN
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      NaN
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
# ...

# %%
data.shape
# Out:
# (10866, 21)

# %%
data.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
data.nunique()
# Out:
# id                      10865
# imdb_id                 10855
# popularity              10814
# budget                    557
# revenue                  4702
# original_title          10571
# cast                    10719
# homepage                 2896
# director                 5067
# tagline                  7997
# keywords                 8804
# overview                10847
# runtime                   247
# genres                   2039
# production_companies     7445
# release_date             5909
# vote_count               1289
# vote_average               72
# release_year               56
# budget_adj               2614
# revenue_adj              4840
# dtype: int64

# %%
data.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
data.mean()
data.fillna(data.mean())
data
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
data.drop(columns=['vote_count','cast','overview','imdb_id','revenue_adj','homepage','tagline','budget_adj','keywords'],inplace=True,axis=0)

# %%
data = data[data['revenue'] != 0]
data = data[data['budget'] != 0]

# %%
data
# Out:
#            id  popularity     budget     revenue  \
# 0      135397   32.985763  150000000  1513528810
# 1       76341   28.419936  150000000   378436354
# 2      262500   13.112507  110000000   295238201
# 3      140607   11.173104  200000000  2068178225
# 4      168259    9.335014  190000000  1506249360
# ...       ...         ...        ...         ...
# 10822     396    0.670274    7500000    33736689
# 10828    5780    0.402730    3000000    13000000
# 10829    6644    0.395668    4653000     6000000
# 10835    5923    0.299911   12000000    20000000
# 10848    2161    0.207257    5115000    12000000
#
#                         original_title           director  runtime  \
# 0                       Jurassic World    Colin Trevorrow      124
# 1                   Mad Max: Fury Road      George Miller      120
# 2                            Insurgent   Robert Schwentke      119
# 3         Star Wars: The Force Awakens        J.J. Abrams      136
# ...

# %%
data.columns
# Out:
# Index(['id', 'popularity', 'budget', 'revenue', 'original_title', 'director',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_average', 'release_year'],
#       dtype='object')

# %%
sum(data.duplicated())
# Out:
# 1

# %%
data.drop_duplicates()
# Out:
#            id  popularity     budget     revenue  \
# 0      135397   32.985763  150000000  1513528810
# 1       76341   28.419936  150000000   378436354
# 2      262500   13.112507  110000000   295238201
# 3      140607   11.173104  200000000  2068178225
# 4      168259    9.335014  190000000  1506249360
# ...       ...         ...        ...         ...
# 10822     396    0.670274    7500000    33736689
# 10828    5780    0.402730    3000000    13000000
# 10829    6644    0.395668    4653000     6000000
# 10835    5923    0.299911   12000000    20000000
# 10848    2161    0.207257    5115000    12000000
#
#                         original_title           director  runtime  \
# 0                       Jurassic World    Colin Trevorrow      124
# 1                   Mad Max: Fury Road      George Miller      120
# 2                            Insurgent   Robert Schwentke      119
# 3         Star Wars: The Force Awakens        J.J. Abrams      136
# ...

# %%
print("Rows With Zero Values In The Budget Column:",data[(data['budget']==0)].shape[0])
print("Rows With Zero Values In The Revenue Column:",data[(data['revenue']==0)].shape[0])
# Out:
# Rows With Zero Values In The Budget Column: 0
# Rows With Zero Values In The Revenue Column: 0

# %%
print("After Removing Unused Columns (Rows,Columns) : ",data.shape)
# Out:
# After Removing Unused Columns (Rows,Columns) :  (3855, 12)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig , ax = plt.subplots(figsize=(20,10))
data.groupby('release_year').count()['id'].plot(kind='bar',fontsize=14,color="#2E86c1")
plt.title('No. of movies released per year', fontsize=19)
plt.xlabel('Years (1967-2015)' , fontsize=17)
plt.ylabel("Number of Movies Released", fontsize=17)
plt.show()

# %%
data.hist(color='DarkBlue',figsize= (10,10));

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(data['budget'],kde=False,hist=True,bins=11,hist_kws=dict(edgecolor="k", linewidth=1))

# %%
sns.distplot(data['revenue'],kde=False,bins=[0, 5, 10, 15, 20, 25, 30],hist_kws=dict(edgecolor="g", linewidth=1),color='Green')

# %%
sns.lmplot('vote_average', 'revenue', data=data)

# %%
#to see outliers
sns.boxplot(x=data['budget'])

# %%
sns.distplot(data['budget']);

# %%
#Q1) Which are the movies with the third lowest and third highest budget?

# %%
data.groupby('release_year').count()['id'].plot(xticks = np.arange(1960,2016,5))
sns.set(rc={'figure.figsize':(10,5)})
plt.title("Year Vs Number Of Movies",fontsize = 14)
plt.xlabel('Release year',fontsize = 13)
plt.ylabel('Number Of Movies',fontsize = 13)
sns.set_style("whitegrid")

# %%
data.nlargest(3,'budget')
# Out:
#          id  popularity     budget     revenue  \
# 2244  46528    0.250540  425000000    11087569
# 3375   1865    4.955130  380000000  1021683000
# 7387    285    4.965391  300000000   961000000
#
#                                    original_title        director  runtime  \
# 2244                            The Warrior's Way      Sngmoo Lee      100
# 3375  Pirates of the Caribbean: On Stranger Tides    Rob Marshall      136
# 7387     Pirates of the Caribbean: At World's End  Gore Verbinski      169
#
#                                          genres  \
# 2244  Adventure|Fantasy|Action|Western|Thriller
# 3375                   Adventure|Action|Fantasy
# 7387                   Adventure|Fantasy|Action
#
#                                    production_companies release_date  \
# 2244                           Boram Entertainment Inc.      12/2/10
# 3375  Walt Disney Pictures|Jerry Bruckheimer Films|M...      5/11/11
# ...

# %%
data.nsmallest(3,'budget')
# Out:
#          id  popularity  budget  revenue           original_title  \
# 2618  39964    0.090186       1      100             Lost & Found
# 3581  59296    0.520430       1     1378  Love, Wedding, Marriage
# 8944  14373    0.464188       2       16             Death Wish 2
#
#              director  runtime                 genres  \
# 2618     Jeff Pollack       95         Comedy|Romance
# 3581  Dermot Mulroney       90         Comedy|Romance
# 8944   Michael Winner       88  Action|Crime|Thriller
#
#                                    production_companies release_date  \
# 2618           Alcon Entertainment|Dinamo Entertainment      4/23/99
# 3581  120dB Films|Scion Films|Voodoo Production Serv...       6/3/11
# 8944                                       Cannon Films      2/20/82
#
#       vote_average  release_year
# 2618           4.8          1999
# 3581           5.3          2011
# 8944           5.6          1982

# %%
third_lowest = data.sort_values(['budget']).iloc[2]['original_title']
third_highest = data.sort_values(['budget']).iloc[-3]['original_title']
third_lowest, third_highest
# Out:
# ('Death Wish 2', "Pirates of the Caribbean: At World's End")

# %%
#Q2)What is the average number of words in movie titles between the year 2000-2005?

# %%
import pandas as pd
data = pd.read_csv("C:/Users/SHRUTI KATHURIA/Desktop/Verzeo Project/Minor/tmbd.csv")
li=data.loc[2000: 2005, "original_title"]

# %%
data.columns
temp  = data.where(data['release_year'] <= 2005)
temp  = temp.where(temp['release_year'] >= 2000)
temp = temp[temp['release_year'].notna()]
temp.sort_values('release_year')
# Out:
#            id    imdb_id  popularity      budget      revenue  \
# 8887  44756.0  tt0250440    0.004010         0.0          0.0
# 8740  10473.0  tt0214641    0.502088         0.0          0.0
# 8739   2155.0  tt0184858    0.525341  42000000.0   32168970.0
# 8738  11678.0  tt0190865    0.530739  75000000.0  215663859.0
# 8737  10429.0  tt0159784    0.533792         0.0          0.0
# ...       ...        ...         ...         ...          ...
# 6435   2610.0  tt0338427    0.270403  10284523.0   11588205.0
# 6436  19495.0  tt0374089    0.270053  25000000.0          0.0
# 6437   9701.0  tt0395972    0.269437  35000000.0   25224242.0
# 6439   8382.0  tt0431114    0.246090         0.0          0.0
# 6244   8292.0  tt0430105    1.075427  45000000.0   92374674.0
#
#                     original_title  \
# 8887               Is It Fall Yet?
# 8740  DragonHeart: A New Beginning
# 8739                Reindeer Games
# 8738                Vertical Limit
# 8737                      Takedown
# ...

# %%
temp['original_title']
# Out:
# 2633    The Lord of the Rings: The Fellowship of the Ring
# 2634             Harry Potter and the Philosopher's Stone
# 2635                                     Mulholland Drive
# 2636                                         Donnie Darko
# 2637                                       Monsters, Inc.
#                               ...
# 8883                                         The In Crowd
# 8884                          Phir Bhi Dil Hai Hindustani
# 8885                                     The Tao of Steve
# 8886                                    George Washington
# 8887                                      Is It Fall Yet?
# Name: original_title, Length: 1687, dtype: object

# %%
count = 0
for string in temp['original_title']:
  t = str(string)
  count = count + len(t.split())
avg = count / len(temp)
print(avg)
# Out:
# 2.879668049792531

# %%
#Q3)What is the most common Genre for Vin Diesel & Emma Watson movies?

# %%
# We need to create two empty Dictionaries 
data1= pd.read_csv("C:/Users/SHRUTI KATHURIA/Desktop/Verzeo Project/Minor/tmbd.csv")
vd={}
em={}

for j in range(int(data1.shape[0])):
    
    if type(data.cast[j])==str:
        
        .
        
# Movies in which "Vin Diesel" is present 
        if "Vin Diesel" in data1.cast[j] :
            if data1.genres[j] in vd:
                vd[data1.genres[j]+=1
            else:
                vd[data1.genres[j] =1
        
# Movies in which "Emma Watson" is present 
        if "Emma Watson" in data.cast[j] :
            if data1.genres[j] in em:
                em[data1.genres[j]]+=1
            else:
                em[data1.genres[j]]=1

        
V={}
# Finding the count of each genre in entire Dataset in which "Vin Diesel" is present 

for k,v in vd.items():

# Splitting based on "|" as delimeter
tem= k.split ("|") 
    for ea in tem:
        if ea in V:
            V[ea]+=1*int(v)
        else:
            V[ea]=1*int(v)
    
    
E={}
# Finding the count of each genre in entire Dataset in which "Emma Watson" is present 

for k2,v2 in em.items():
    
# Splitting based on "|" as delimeter
tem2= k2.split("|")     
for ea in tem2:
        if ea in E:
            E[ea]+=1*int(v2)
        else:
            E[ea]=1*int(v2)

In [ ]:
# Finding the Keys with max value of Genre Count 

Vmax= max(V, key=V.get)
Emax= max(E, key=E.get)
print(V)
print("The most common Genre for Vin Diesel :",Vmax)
print(E)
print("The most common Genre for Emma Watson :",Emax,"and Adventure")
# Out:
#   File "<ipython-input-130-a59df10adf74>", line 10
#     .
#     ^
# SyntaxError: invalid syntax

# %%
#Q4) Which are the movies with most and least earned revenue?

# %%
data.nlargest(1,'revenue')
# Out:
#          id    imdb_id  popularity     budget     revenue original_title  \
# 1386  19995  tt0499549    9.432768  237000000  2781505847         Avatar
#
#                                                    cast  \
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
#
#                          homepage       director                      tagline  \
# 1386  http://www.avatarmovie.com/  James Cameron  Enter the World of Pandora.
#
#       ...                                           overview runtime  \
# 1386  ...  In the 22nd century, a paraplegic Marine is di...     162
#
#                                         genres  \
# 1386  Action|Adventure|Fantasy|Science Fiction
#
#                                    production_companies release_date  \
# 1386  Ingenious Film Partners|Twentieth Century Fox ...     12/10/09
#
#      vote_count  vote_average  release_year    budget_adj   revenue_adj
# 1386       8458           7.1          2009  2.408869e+08  2.827124e+09
#
# ...

# %%
data.nsmallest(1,'revenue')
# Out:
#         id    imdb_id  popularity    budget  revenue original_title  \
# 48  265208  tt2231253     2.93234  30000000        0      Wild Card
#
#                                                  cast homepage    director  \
# 48  Jason Statham|Michael Angarano|Milo Ventimigli...      NaN  Simon West
#
#                                         tagline  ...  \
# 48  Never bet against a man with a killer hand.  ...
#
#                                              overview runtime  \
# 48  When a Las Vegas bodyguard with lethal skills ...      92
#
#                   genres                               production_companies  \
# 48  Thriller|Crime|Drama  Current Entertainment|Lionsgate|Sierra / Affin...
#
#    release_date vote_count  vote_average  release_year    budget_adj  \
# 48      1/14/15        481           5.3          2015  2.759999e+07
#
#     revenue_adj
# 48          0.0
#
# [1 rows x 21 columns]

# %%
Revenue_least = data.sort_values(['revenue']).iloc[0]['original_title']
Revenue_most = data.sort_values(['revenue']).iloc[-1]['original_title']
Revenue_least, Revenue_most
# Out:
# ('Manos: The Hands of Fate', 'Avatar')

# %%
#Q5)What is the average runtime of movies in the year 2006?

# %%
data[data.release_year==2006].runtime.mean()
# Out:
# 101.68382352941177

# %%
data.groupby('release_year').mean()['runtime'].plot(xticks = np.arange(1960,2016,5))
sns.set(rc={'figure.figsize':(10,5)})
plt.title("Runtime Vs Year",fontsize = 14)
plt.xlabel('Year',fontsize = 13)
plt.ylabel('Runtime',fontsize = 13)
sns.set_style("whitegrid")

# %%
#Q6)Name any 3 production companies which have invested money in worse revenue movies?

# %%
data.nsmallest(3,'revenue')
# Out:
#         id    imdb_id  popularity    budget  revenue          original_title  \
# 48  265208  tt2231253    2.932340  30000000        0               Wild Card
# 67  334074  tt3247714    2.331636  20000000        0                Survivor
# 74  347096  tt3478232    2.165433         0        0  Mythica: The Darkspore
#
#                                                  cast  \
# 48  Jason Statham|Michael Angarano|Milo Ventimigli...
# 67  Pierce Brosnan|Milla Jovovich|Dylan McDermott|...
# 74  Melanie Stone|Kevin Sorbo|Adam Johnson|Jake St...
#
#                                      homepage        director  \
# 48                                        NaN      Simon West
# 67                  http://survivormovie.com/  James McTeigue
# 74  http://www.mythicamovie.com/#!blank/wufvh   Anne K. Black
#
#                                         tagline  ...  \
# 48  Never bet against a man with a killer hand.  ...
# 67           His Next Target is Now Hunting Him  ...
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("C:/Users/SHRUTI KATHURIA/Desktop/Verzeo Project/Minor/tmbd.csv")   
data.info()

df=data.drop(columns=['id', 'popularity', 'budget', 'original_title','cast','director', 'keywords', 'runtime', 'genres', 'release_date','vote_count', 'vote_average', 'release_year'])

df.isnull().sum()

import warnings
warnings.filterwarnings("ignore")

df.dropna(subset=['production_companies'],inplace=True)
df=df[(df['revenue']>0)]

df.nunique()

# We are calculating the mean revenue of each production company. As there are like x different production companies, we should get x rows.

df_=df.groupby('production_companies').mean()

df_=df_.sort_values('revenue')
df_.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...
